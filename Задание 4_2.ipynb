# %%
import numpy
import pandas
import matplotlib.pyplot
tab=pandas.DataFrame()
tab.insert(0,'Число',range(1,11))
tab.insert(1,'Квадраты',tab['Число']**2)
tab2=pandas.DataFrame()
tab2=tab[tab['Число']%2==0]
tab2=tab2.drop(['Число'],axis='columns')
print(tab2)
print(squares)
# Out:
#    Квадраты
# 1         4
# 3        16
# 5        36
# 7        64
# 9       100
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]
